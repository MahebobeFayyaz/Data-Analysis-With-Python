# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Line plot

# %%
sns.lineplot(x='size',y='total_bill',data =tips)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x='day',y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## violin plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Hitograms

# %%
sns.histplot(tips['total_bill'], bins = 10, kde=True, color='brown')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### KDE Plot

# %%
sns.kdeplot(tips['total_bill'], fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(tips)

# %% [markdown]
# ## Heat Map

# %%
tips_corr = tips.corr()
tips_corr
# Out:
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_9856\3728204316.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips_corr = tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data=tips_corr, annot = True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
df=pd.read_excel("Datasets/sample-chocolate-sales-data-1.xlsx")

# %%
df.head(2)
# Out:
#       Sales Person               Product Country       Date   Amount  Boxes  \
# 0   Jehu Rudeforth            White Choc     USA 2023-01-02  5879.25    236
# 1  Roddy Speechley  Choco Coated Almonds      UK 2023-01-02  2110.50    141
#
#   Order Status
# 0    Delivered
# 1    Delivered

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Country',y='Amount', data = df, estimator = sum)
# Out:
# <Axes: xlabel='Country', ylabel='Amount'>
